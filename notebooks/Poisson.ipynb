# %%
import numpy as np
import matplotlib.pyplot as plt
array = np.random.poisson(100,1024**2).astype(np.uint8)
print(array.dtype)
plt.plot(array)
plt.show()

file = open("poisson",'w')
array.tofile(file)
file.close
# Out:
# uint8
# <function TextIOWrapper.close()>
